# %% [markdown]
# # T10 Dimensionality reduction

# %% [markdown]
# ## Principal component analysis

# %% [markdown]
# We generate an artifical dataset consisting of three variables. The three variables show some dynamics as function of time which varies from [0,10] s.
#
# We will perform a Principal Component Analysis on this dataset. The aim is to find two latent varaibles which could account for the dynamics of the original three variables.

# %% [markdown]
# Let's start by importing the necessary libraries and creating the variables.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %matplotlib notebook

# generating three time-dependent variables 
t = np.arange(1000)/100. # time array 
x1 = np.sin(t) + t/1. + np.random.rand(len(t))/2.
x2 = np.sin(t) - t/1. + np.random.rand(len(t))/2.
x3 = t/1. + np.random.rand(len(t))/2.

# %% [markdown]
# #### Visualize the raw data
#
# As usual let's start by plotting the data first. Simply display the three variables as function of time.

# %%
fig = plt.figure()

ax = fig.add_subplot(111)
ax.plot(t,x1)
ax.plot(t,x2)
ax.plot(t,x3)

plt.xlabel('time')
plt.ylabel('unit')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# #### Visualize the raw data in 3D
#
# Let's also look at the three variables in the 3-dimensional space, where x1, x2 and x3 are used as x, y and z. Note that time is not explictely plotted in this depiction. It is implicit in the trajectory of the data.
#
# What do you observe when rotating the axes (use the interactive modus through `%matplotlib notebook`)?

# %%
from mpl_toolkits import mplot3d
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot3D(x1, x2, x3)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('x3')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# One can find a plane in which all the dynamics of the trajectory happens. In other words, the trajectory lies in a plane. PCA tries to find this plane as would be a reduction in dimensions from 3 to 2.

# %% [markdown]
# #### Check the correlation structure between variables
#
# PCA removes correlations between variables. Let's see whether correlations between the three variables exist. In other words, let's calculate the covariance matrix.

# %%
covMatrix = np.cov((x1,x2,x3))
print(covMatrix)
# Out:
# [[ 8.56352105 -7.91709778  8.22740939]
#  [-7.91709778  9.06480312 -8.48022757]
#  [ 8.22740939 -8.48022757  8.37253044]]

# %% [markdown]
# The diagonal elements quantify the variance of `x1`, `x2` and `x3`. The off-diagonal elements quanitfy the covariance between the three observed variables, *i.e.*, `cov(x1,x2)`, `cov(x1,x3)` and `cov(x2,x3)`. These elements are not-zero, indicating that the three obeservables co-vary.

# %% [markdown]
# #### Calculate the PCA
#
# Let's now move on to perform the PCA analysis. We will use the scikit learn module, specifically the `PCA` function in `sklearn.decomposition`. We will look at the PCA components (via `pca.components_`, the explained variance (via `pca.explained_variance_`) and the covariance matrix from the PCA (via `pca.get_covariance()`).

# %%
# perform PCA analysis 
X = np.column_stack((x1,x2,x3)) # first we have to concatenate the three variables 
pca = PCA(n_components=3)
pca.fit(X)

print('PCA components :',pca.components_)
print('PCA explained variance :',pca.explained_variance_)
print('Covariance matrix :',pca.get_covariance())
# Out:
# PCA components : [[-0.56853187  0.58631443 -0.5770675 ]
#  [-0.71510485 -0.69899423 -0.00566747]
#  [-0.40668977  0.40944163  0.81667679]]
# PCA explained variance : [2.49381998e+01 8.94707647e-01 1.99026549e-02]
# Covariance matrix : [[ 8.52155953 -7.86895138  8.17877193]
#  [-7.86895138  9.01335493 -8.42746594]
#  [ 8.17877193 -8.42746594  8.31789568]]

# %% [markdown]
# #### Visualize principal compnents in 3D
#
# Let's try to plot the new basis vectors in the 3-dimensional space.

# %%
comp = pca.components_

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot3D(x1, x2, x3)
ax.plot([0,3*comp[0,0]],[0,3*comp[0,1]],[0,3*comp[0,2]])
ax.plot([0,3*comp[1,0]],[0,3*comp[1,1]],[0,3*comp[1,2]])
ax.plot([0,3*comp[2,0]],[0,3*comp[2,1]],[0,3*comp[2,2]])
#### Visualize the raw data
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# The two first eigenvectors from the PCA span the plane in which the trajectory lies.

# %% [markdown]
# #### Transform the original data in the PCA space
#
# Next, let's now convert the data to the new space spanned by the principal components by using `pca.transform([original data])`. Plot the two latent variables.

# %%
X_pca = pca.transform(X)

print("original shape :   ", X.shape)
print("transformed shape :", X_pca.shape)

# do PCA and plot principal components
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.plot(t,X_pca[:,0])
ax1.plot(t,X_pca[:,1])

plt.show()
# Out:
# original shape :    (1000, 3)
# transformed shape : (1000, 3)
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# #### Perform inverse tranformation
#
# Finally, let's look at the inverse tranformation, i.e., the transformation from the PCA space back to the original coordinate system. Perform the inverse transformation for the three variables.

# %%
meanX = np.mean(X,axis=0)

Xhat = pca.inverse_transform(X_pca)
Xhat2 = np.dot(X_pca,comp) + meanX

fig = plt.figure()
ax0 = fig.add_subplot(1,1,1)
ax0.plot(t,x1)
ax0.plot(t,Xhat[:,0])
ax0.plot(t,Xhat2[:,0])
ax0.plot(t,X_pca[:,0]*comp[0,0]+X_pca[:,1]*comp[1,0]+meanX[0])
#ax0.plot(t,X_pca[:,1]*comp[1,0]+meanX[0],ls='--')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# Try the inverse tranformation without taking into accout the first principal component. What does this mean?

# %%
# reconstract original data without 1st principal component
Xhat = np.dot(X_pca[:,1:], pca.components_[1:,:])
Xhat += meanX

fig = plt.figure()
ax2 = fig.add_subplot(1,1,1)

ax2.plot(t,Xhat[:,0])
ax2.plot(t,Xhat[:,1])
ax2.plot(t,Xhat[:,2])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# The reconstruction without the 1. principal components retains oscillations in the original variables but omits the linear function (which is the 1. principal component). Such a transformation can be useful if one is interest in specific aspects of the data and wants to single them out.

# %% [markdown]
# ## The end
